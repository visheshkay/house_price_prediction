# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import matplotlib
matplotlib.rcParams["figure.figsize"] = (20,10)

# %%
df1 = pd.read_csv("/Users/visheshkondaveeti/Downloads/Bengaluru_House_Data.csv")
df1.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
df1.groupby('area_type')['area_type'].agg("count")
# Out:
# area_type
# Built-up  Area          2418
# Carpet  Area              87
# Plot  Area              2025
# Super built-up  Area    8790
# Name: area_type, dtype: int64

# %%
df2 = df1.drop(["area_type","society"],axis="columns")
df2.head()
# Out:
#     availability                  location       size total_sqft  bath  \
# 0         19-Dec  Electronic City Phase II      2 BHK       1056   2.0
# 1  Ready To Move          Chikka Tirupathi  4 Bedroom       2600   5.0
# 2  Ready To Move               Uttarahalli      3 BHK       1440   2.0
# 3  Ready To Move        Lingadheeranahalli      3 BHK       1521   3.0
# 4  Ready To Move                  Kothanur      2 BHK       1200   2.0
#
#    balcony   price
# 0      1.0   39.07
# 1      3.0  120.00
# 2      3.0   62.00
# 3      1.0   95.00
# 4      1.0   51.00

# %%
df2.isnull().sum()
# Out:
# availability      0
# location          1
# size             16
# total_sqft        0
# bath             73
# balcony         609
# price             0
# dtype: int64

# %%
df2
# Out:
#         availability                  location       size total_sqft  bath  \
# 0             19-Dec  Electronic City Phase II      2 BHK       1056   2.0
# 1      Ready To Move          Chikka Tirupathi  4 Bedroom       2600   5.0
# 2      Ready To Move               Uttarahalli      3 BHK       1440   2.0
# 3      Ready To Move        Lingadheeranahalli      3 BHK       1521   3.0
# 4      Ready To Move                  Kothanur      2 BHK       1200   2.0
# ...              ...                       ...        ...        ...   ...
# 13315  Ready To Move                Whitefield  5 Bedroom       3453   4.0
# 13316  Ready To Move             Richards Town      4 BHK       3600   5.0
# 13317  Ready To Move     Raja Rajeshwari Nagar      2 BHK       1141   2.0
# 13318         18-Jun           Padmanabhanagar      4 BHK       4689   4.0
# 13319  Ready To Move              Doddathoguru      1 BHK        550   1.0
#
#        balcony   price
# 0          1.0   39.07
# ...

# %%
df2=df2.dropna()
df2.isnull().sum()
# Out:
# availability    0
# location        0
# size            0
# total_sqft      0
# bath            0
# balcony         0
# price           0
# dtype: int64

# %%
df2['size'].unique()
# Out:
# array(['2 BHK', '4 Bedroom', '3 BHK', '3 Bedroom', '1 BHK', '1 RK',
#        '4 BHK', '1 Bedroom', '2 Bedroom', '6 Bedroom', '8 Bedroom',
#        '7 Bedroom', '5 BHK', '7 BHK', '6 BHK', '5 Bedroom', '11 BHK',
#        '9 BHK', '9 Bedroom', '27 BHK', '11 Bedroom', '43 Bedroom',
#        '14 BHK', '8 BHK', '12 Bedroom', '10 Bedroom', '13 BHK'],
#       dtype=object)

# %%
df2['bhk']=df2['size'].apply(lambda x: int(x.split()[0]))
df2
# Out:
# /var/folders/k0/wbqwmj5s7790wcm_6mhpvf380000gn/T/ipykernel_1746/2046816523.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['bhk']=df2['size'].apply(lambda x: int(x.split()[0]))
#         availability                  location       size total_sqft  bath  \
# 0             19-Dec  Electronic City Phase II      2 BHK       1056   2.0
# 1      Ready To Move          Chikka Tirupathi  4 Bedroom       2600   5.0
# 2      Ready To Move               Uttarahalli      3 BHK       1440   2.0
# 3      Ready To Move        Lingadheeranahalli      3 BHK       1521   3.0
# 4      Ready To Move                  Kothanur      2 BHK       1200   2.0
# ...              ...                       ...        ...        ...   ...
# ...

# %%
df2['bhk'].unique()
# Out:
# array([ 2,  4,  3,  1,  6,  8,  7,  5, 11,  9, 27, 43, 14, 12, 10, 13])

# %%
df2[df2['bhk']>15]
# Out:
#        availability                   location        size total_sqft  bath  \
# 1718  Ready To Move  2Electronic City Phase II      27 BHK       8000  27.0
# 4684  Ready To Move                Munnekollal  43 Bedroom       2400  40.0
#
#       balcony  price  bhk
# 1718      0.0  230.0   27
# 4684      0.0  660.0   43

# %%
df2['total_sqft'].unique()
# Out:
# array(['1056', '2600', '1440', ..., '1133 - 1384', '774', '4689'],
#       dtype=object)

# %%
def isfloat(x):
    try:
        float(x)
    except:
        return False
    return True

# %%
df2[~ df2['total_sqft'].apply(isfloat)]
# Out:
#         availability            location   size   total_sqft  bath  balcony  \
# 30            19-Dec           Yelahanka  4 BHK  2100 - 2850   4.0      0.0
# 122           18-Mar              Hebbal  4 BHK  3067 - 8156   4.0      0.0
# 137           19-Mar  8th Phase JP Nagar  2 BHK  1042 - 1105   2.0      0.0
# 165           18-Dec            Sarjapur  2 BHK  1145 - 1340   2.0      0.0
# 188    Ready To Move            KR Puram  2 BHK  1015 - 1540   2.0      0.0
# ...              ...                 ...    ...          ...   ...      ...
# 12975         20-Aug          Whitefield  2 BHK   850 - 1060   2.0      0.0
# 12990         18-May      Talaghattapura  3 BHK  1804 - 2273   3.0      0.0
# 13059  Ready To Move              Harlur  2 BHK  1200 - 1470   2.0      0.0
# 13265         20-Sep               Hoodi  2 BHK  1133 - 1384   2.0      0.0
# 13299         18-Dec          Whitefield  4 BHK  2830 - 2882   5.0      0.0
#
#          price  bhk
# 30     186.000    4
# ...

# %%
def findavg(s):
    t = s.split('-')
    ans=None
    if(len(t)==2):
        l,r = t[0],t[1]
        return ((float(l)+float(r))/2)
    try:
        return float(s)
    except:
        return None

# %%
findavg('2830 - 2882'	)
# Out:
# 2856.0

# %%
findavg('2540')
# Out:
# 2540.0

# %%
findavg('45000mtr')

# %%
df4 = df2.copy()
df4['total_sqft']=df2['total_sqft'].apply(findavg)

# %%
df4
# Out:
#         availability                  location       size  total_sqft  bath  \
# 0             19-Dec  Electronic City Phase II      2 BHK      1056.0   2.0
# 1      Ready To Move          Chikka Tirupathi  4 Bedroom      2600.0   5.0
# 2      Ready To Move               Uttarahalli      3 BHK      1440.0   2.0
# 3      Ready To Move        Lingadheeranahalli      3 BHK      1521.0   3.0
# 4      Ready To Move                  Kothanur      2 BHK      1200.0   2.0
# ...              ...                       ...        ...         ...   ...
# 13314  Ready To Move         Green Glen Layout      3 BHK      1715.0   3.0
# 13315  Ready To Move                Whitefield  5 Bedroom      3453.0   4.0
# 13317  Ready To Move     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0
# 13318         18-Jun           Padmanabhanagar      4 BHK      4689.0   4.0
# 13319  Ready To Move              Doddathoguru      1 BHK       550.0   1.0
#
#        balcony   price  bhk
# ...

# %%
df4[~ df4['total_sqft'].apply(isfloat)]
# Out:
# Empty DataFrame
# Columns: [availability, location, size, total_sqft, bath, balcony, price, bhk]
# Index: []

# %%
df5 = df4.copy()
df5['price_per_sqft']= (df4['price']*100000/df4['total_sqft'])

# %%
df5.head()
# Out:
#     availability                  location       size  total_sqft  bath  \
# 0         19-Dec  Electronic City Phase II      2 BHK      1056.0   2.0
# 1  Ready To Move          Chikka Tirupathi  4 Bedroom      2600.0   5.0
# 2  Ready To Move               Uttarahalli      3 BHK      1440.0   2.0
# 3  Ready To Move        Lingadheeranahalli      3 BHK      1521.0   3.0
# 4  Ready To Move                  Kothanur      2 BHK      1200.0   2.0
#
#    balcony   price  bhk  price_per_sqft
# 0      1.0   39.07    2     3699.810606
# 1      3.0  120.00    4     4615.384615
# 2      3.0   62.00    3     4305.555556
# 3      1.0   95.00    3     6245.890861
# 4      1.0   51.00    2     4250.000000

# %%
len(df5['location'].unique())
# Out:
# 1265

# %%
df5['location']=df5['location'].apply(lambda x: x.strip())

# %%
location_stats = df5.groupby('location')['location'].agg('count')

# %%
location_stats
# Out:
# location
# 1 Annasandrapalya                                  1
# 1 Giri Nagar                                       1
# 1 Ramamurthy Nagar                                 1
# 12th cross srinivas nagar banshankari 3rd stage    1
# 1A Block Koramangala                               1
#                                                   ..
# south                                              2
# t.c palya                                          1
# tc.palya                                           4
# vinayakanagar                                      1
# whitefiled                                         1
# Name: location, Length: 1254, dtype: int64

# %%
len(location_stats<=10)
# Out:
# 1254

# %%
location_stats_ltt = location_stats[lambda x: x<=10]

# %%
location_stats_ltt
# Out:
# location
# 1 Annasandrapalya                                  1
# 1 Giri Nagar                                       1
# 1 Ramamurthy Nagar                                 1
# 12th cross srinivas nagar banshankari 3rd stage    1
# 1A Block Koramangala                               1
#                                                   ..
# south                                              2
# t.c palya                                          1
# tc.palya                                           4
# vinayakanagar                                      1
# whitefiled                                         1
# Name: location, Length: 1017, dtype: int64

# %%
df5['location']=df5['location'].apply(lambda x: 'other' if x in location_stats_ltt else x)

# %%
df5
# Out:
#         availability                  location       size  total_sqft  bath  \
# 0             19-Dec  Electronic City Phase II      2 BHK      1056.0   2.0
# 1      Ready To Move          Chikka Tirupathi  4 Bedroom      2600.0   5.0
# 2      Ready To Move               Uttarahalli      3 BHK      1440.0   2.0
# 3      Ready To Move        Lingadheeranahalli      3 BHK      1521.0   3.0
# 4      Ready To Move                  Kothanur      2 BHK      1200.0   2.0
# ...              ...                       ...        ...         ...   ...
# 13314  Ready To Move         Green Glen Layout      3 BHK      1715.0   3.0
# 13315  Ready To Move                Whitefield  5 Bedroom      3453.0   4.0
# 13317  Ready To Move     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0
# 13318         18-Jun           Padmanabhanagar      4 BHK      4689.0   4.0
# 13319  Ready To Move              Doddathoguru      1 BHK       550.0   1.0
#
#        balcony   price  bhk  price_per_sqft
# ...

# %%
df5['location'].unique()
df5.groupby('location')['location'].unique()
# Out:
# location
# 1st Block Jayanagar                [1st Block Jayanagar]
# 1st Phase JP Nagar                  [1st Phase JP Nagar]
# 2nd Phase Judicial Layout    [2nd Phase Judicial Layout]
# 2nd Stage Nagarbhavi              [2nd Stage Nagarbhavi]
# 5th Phase JP Nagar                  [5th Phase JP Nagar]
#                                         ...
# Yelahanka                                    [Yelahanka]
# Yelahanka New Town                  [Yelahanka New Town]
# Yelenahalli                                [Yelenahalli]
# Yeshwanthpur                              [Yeshwanthpur]
# other                                            [other]
# Name: location, Length: 238, dtype: object

# %%
df5[df5['total_sqft']/df5['bhk']<=200]
# Out:
#         availability             location       size  total_sqft  bath  \
# 68     Ready To Move  Devarachikkanahalli  8 Bedroom      1350.0   7.0
# 70     Ready To Move                other  3 Bedroom       500.0   3.0
# 89     Ready To Move         Rajaji Nagar  6 Bedroom       710.0   6.0
# 119    Ready To Move          Hennur Road  2 Bedroom       276.0   3.0
# 129    Ready To Move   Vishwapriya Layout  7 Bedroom       950.0   7.0
# ...              ...                  ...        ...         ...   ...
# 13073  Ready To Move           Nagarbhavi  4 Bedroom       600.0   3.0
# 13112  Ready To Move             Nagavara  3 Bedroom       440.0   3.0
# 13198  Ready To Move                other  8 Bedroom      1200.0   8.0
# 13221  Ready To Move                other  9 Bedroom      1178.0   9.0
# 13303  Ready To Move       Vidyaranyapura  5 Bedroom       774.0   5.0
#
#        balcony  price  bhk  price_per_sqft
# 68         0.0   85.0    8     6296.296296
# ...

# %%
df6 = df5[~(df5['total_sqft']/df5['bhk']<=200)]
df6.head(10)
# Out:
#      availability                  location       size  total_sqft  bath  \
# 0          19-Dec  Electronic City Phase II      2 BHK      1056.0   2.0
# 1   Ready To Move          Chikka Tirupathi  4 Bedroom      2600.0   5.0
# 2   Ready To Move               Uttarahalli      3 BHK      1440.0   2.0
# 3   Ready To Move        Lingadheeranahalli      3 BHK      1521.0   3.0
# 4   Ready To Move                  Kothanur      2 BHK      1200.0   2.0
# 5   Ready To Move                Whitefield      2 BHK      1170.0   2.0
# 8   Ready To Move              Marathahalli      3 BHK      1310.0   3.0
# 10         18-Feb                Whitefield      3 BHK      1800.0   2.0
# 11  Ready To Move                Whitefield  4 Bedroom      2785.0   5.0
# 12  Ready To Move        7th Phase JP Nagar      2 BHK      1000.0   2.0
#
#     balcony   price  bhk  price_per_sqft
# 0       1.0   39.07    2     3699.810606
# 1       3.0  120.00    4     4615.384615
# ...

# %%
df6['price_per_sqft'].describe()
# Out:
# count     12289.000000
# mean       6318.665622
# std        4093.762167
# min         267.829813
# 25%        4204.204204
# 50%        5293.339215
# 75%        6944.444444
# max      176470.588235
# Name: price_per_sqft, dtype: float64

# %%
def price_per_sqft_outliers(df6):
    df_out = pd.DataFrame()
    for key,subdf in df6.groupby('location'):
        m = np.mean(subdf['price_per_sqft'])
        st = np.std(subdf['price_per_sqft'])
        reduced_df = subdf[(subdf['price_per_sqft']>(m-st)) & (subdf['price_per_sqft']<=(m+st))]
        df_out = pd.concat([df_out,reduced_df],ignore_index=True)
    return df_out

# %%
df7 =  price_per_sqft_outliers(df6)

# %%
df7
# Out:
#         availability             location       size  total_sqft  bath  \
# 0             20-May  1st Block Jayanagar      4 BHK      2850.0   4.0
# 1             18-Jun  1st Block Jayanagar      3 BHK      1630.0   3.0
# 2      Ready To Move  1st Block Jayanagar      3 BHK      1875.0   2.0
# 3             15-Dec  1st Block Jayanagar      3 BHK      1200.0   2.0
# 4             18-Jun  1st Block Jayanagar      2 BHK      1235.0   2.0
# ...              ...                  ...        ...         ...   ...
# 10119  Ready To Move                other      2 BHK      1256.0   2.0
# 10120  Ready To Move                other      2 BHK      1353.0   2.0
# 10121         18-Jan                other  1 Bedroom       812.0   1.0
# 10122         18-Jul                other      3 BHK      1440.0   2.0
# 10123  Ready To Move                other      2 BHK      1075.0   2.0
#
#        balcony   price  bhk  price_per_sqft
# 0          1.0  428.00    4    15017.543860
# ...

# %%
df7['price_per_sqft'].describe()
# Out:
# count    10124.000000
# mean      5639.415035
# std       2249.829189
# min       1300.000000
# 25%       4227.634692
# 50%       5165.338612
# 75%       6412.533355
# max      24000.000000
# Name: price_per_sqft, dtype: float64

# %%
df7[df7['bath']>df7['bhk']]
# Out:
#         availability              location       size  total_sqft  bath  \
# 9      Ready To Move    1st Phase JP Nagar      3 BHK      2065.0   4.0
# 14     Ready To Move    1st Phase JP Nagar      1 BHK       840.0   2.0
# 22     Ready To Move    1st Phase JP Nagar      4 BHK      2615.0   5.0
# 33     Ready To Move  2nd Stage Nagarbhavi  6 Bedroom      3000.0   8.0
# 34     Ready To Move  2nd Stage Nagarbhavi  6 Bedroom      2400.0   8.0
# ...              ...                   ...        ...         ...   ...
# 10001  Ready To Move                 other  3 Bedroom       760.0   4.0
# 10056  Ready To Move                 other      2 BHK       600.0   3.0
# 10076         18-Jul                 other      4 BHK      2710.0   5.0
# 10086  Ready To Move                 other      4 BHK      6652.0   6.0
# 10093  Ready To Move                 other  4 Bedroom      6688.0   6.0
#
#        balcony  price  bhk  price_per_sqft
# 9          1.0  210.0    3    10169.491525
# ...

# %%
plt.hist(df7['bath'],rwidth=0.8)
plt.xlabel("No of bathrooms")
plt.ylabel("count")
plt.show()

# %%
df8 = df7[df7['bath']<=df7['bhk']+2]

# %%
df8
# Out:
#         availability             location       size  total_sqft  bath  \
# 0             20-May  1st Block Jayanagar      4 BHK      2850.0   4.0
# 1             18-Jun  1st Block Jayanagar      3 BHK      1630.0   3.0
# 2      Ready To Move  1st Block Jayanagar      3 BHK      1875.0   2.0
# 3             15-Dec  1st Block Jayanagar      3 BHK      1200.0   2.0
# 4             18-Jun  1st Block Jayanagar      2 BHK      1235.0   2.0
# ...              ...                  ...        ...         ...   ...
# 10119  Ready To Move                other      2 BHK      1256.0   2.0
# 10120  Ready To Move                other      2 BHK      1353.0   2.0
# 10121         18-Jan                other  1 Bedroom       812.0   1.0
# 10122         18-Jul                other      3 BHK      1440.0   2.0
# 10123  Ready To Move                other      2 BHK      1075.0   2.0
#
#        balcony   price  bhk  price_per_sqft
# 0          1.0  428.00    4    15017.543860
# ...

# %%
dummies = pd.get_dummies(df8['location'])
dummies
# Out:
#        1st Block Jayanagar  1st Phase JP Nagar  2nd Phase Judicial Layout  \
# 0                     True               False                      False
# 1                     True               False                      False
# 2                     True               False                      False
# 3                     True               False                      False
# 4                     True               False                      False
# ...                    ...                 ...                        ...
# 10119                False               False                      False
# 10120                False               False                      False
# 10121                False               False                      False
# 10122                False               False                      False
# 10123                False               False                      False
#
#        2nd Stage Nagarbhavi  5th Phase JP Nagar  6th Phase JP Nagar  \
# ...

# %%
df9 = pd.concat([df8,dummies],axis='columns')
df9
# Out:
#         availability             location       size  total_sqft  bath  \
# 0             20-May  1st Block Jayanagar      4 BHK      2850.0   4.0
# 1             18-Jun  1st Block Jayanagar      3 BHK      1630.0   3.0
# 2      Ready To Move  1st Block Jayanagar      3 BHK      1875.0   2.0
# 3             15-Dec  1st Block Jayanagar      3 BHK      1200.0   2.0
# 4             18-Jun  1st Block Jayanagar      2 BHK      1235.0   2.0
# ...              ...                  ...        ...         ...   ...
# 10119  Ready To Move                other      2 BHK      1256.0   2.0
# 10120  Ready To Move                other      2 BHK      1353.0   2.0
# 10121         18-Jan                other  1 Bedroom       812.0   1.0
# 10122         18-Jul                other      3 BHK      1440.0   2.0
# 10123  Ready To Move                other      2 BHK      1075.0   2.0
#
#        balcony   price  bhk  price_per_sqft  1st Block Jayanagar  ...  \
# ...

# %%
df10 = df9.drop(['availability','location','size'],axis='columns')
df10.head()
# Out:
#    total_sqft  bath  balcony  price  bhk  price_per_sqft  1st Block Jayanagar  \
# 0      2850.0   4.0      1.0  428.0    4    15017.543860                 True
# 1      1630.0   3.0      2.0  194.0    3    11901.840491                 True
# 2      1875.0   2.0      3.0  235.0    3    12533.333333                 True
# 3      1200.0   2.0      0.0  130.0    3    10833.333333                 True
# 4      1235.0   2.0      2.0  148.0    2    11983.805668                 True
#
#    1st Phase JP Nagar  2nd Phase Judicial Layout  2nd Stage Nagarbhavi  ...  \
# 0               False                      False                 False  ...
# 1               False                      False                 False  ...
# 2               False                      False                 False  ...
# 3               False                      False                 False  ...
# 4               False                      False                 False  ...
#
# ...

# %%
X = df10.drop('price',axis='columns')
X.head()
# Out:
#    total_sqft  bath  balcony  bhk  price_per_sqft  1st Block Jayanagar  \
# 0      2850.0   4.0      1.0    4    15017.543860                 True
# 1      1630.0   3.0      2.0    3    11901.840491                 True
# 2      1875.0   2.0      3.0    3    12533.333333                 True
# 3      1200.0   2.0      0.0    3    10833.333333                 True
# 4      1235.0   2.0      2.0    2    11983.805668                 True
#
#    1st Phase JP Nagar  2nd Phase Judicial Layout  2nd Stage Nagarbhavi  \
# 0               False                      False                 False
# 1               False                      False                 False
# 2               False                      False                 False
# 3               False                      False                 False
# 4               False                      False                 False
#
#    5th Phase JP Nagar  ...  Vishveshwarya Layout  Vishwapriya Layout  \
# ...

# %%
y = df10['price']
y
# Out:
# 0        428.00
# 1        194.00
# 2        235.00
# 3        130.00
# 4        148.00
#           ...
# 10119     65.00
# 10120    110.00
# 10121     26.00
# 10122     63.93
# 10123     48.00
# Name: price, Length: 10120, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=10)

# %%
from sklearn.linear_model import LinearRegression
linear_model = LinearRegression()
linear_model.fit(X_train,y_train)
linear_model.score(X_test,y_test)
# Out:
# 0.9441698364280523

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import ShuffleSplit
cv = ShuffleSplit(n_splits=5,test_size=0.2,random_state=0)
cross_val_score(linear_model,X,y,cv=cv)
print(sum(list(cross_val_score(linear_model,X,y,cv=cv)))/5)
# Out:
# 0.8934836742640669

# %%
from sklearn.model_selection  import GridSearchCV
from sklearn.linear_model import Lasso
from sklearn.tree import DecisionTreeRegressor

def find_best_model_using_gridsearchcv(X,y):
    algos= {
        'linear_regression':{
            'model':LinearRegression(),
            'parameters':{
            }
        },
        'lasso':{
            'model':Lasso(),
            'parameters':{
                'alpha':[1,2],
                'selection':['random','cyclic']
            }
        },
        'decision_tree':{
            'model':DecisionTreeRegressor(),
            'parameters':{
                'criterion':['mse','friedman_mse'],
                'splitter':['best','random']
            }
        }
    }
    scores = [] # a list to store scores
    cv = ShuffleSplit(n_splits=5,test_size=0.2,random_state=0)
    for algo,config in algos.items():
        gs = GridSearchCV(config['model'],config['parameters'],cv=cv,return_train_score=False)
        gs.fit(X,y)
        scores.append({
            'model':algo,
            'best_score':gs.best_score_,
            'best_params':gs.best_params_
        })
    return pd.DataFrame(scores,columns=['model','best_score','best_params'])

# %%
find_best_model_using_gridsearchcv(X,y)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/model_selection/_validation.py:540: FitFailedWarning:
# 10 fits failed out of a total of 20.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
# ...

# %%
from sklearn.tree import DecisionTreeRegressor
drm = DecisionTreeRegressor()
drm.fit(X_train,y_train)
drm.score(X_test,y_test)
# Out:
# 0.9787842329738242

# %%
cross_val_score(drm,X,y,cv=cv)
print(sum(list(cross_val_score(drm,X,y,cv=cv)))/5)
# Out:
# 0.9096272221852091

# %%
X_train
# Out:
#       total_sqft  bath  balcony  bhk  price_per_sqft  1st Block Jayanagar  \
# 6216      1346.0   2.0      1.0    2     5171.619614                False
# 7443      1160.0   2.0      2.0    2     3362.068966                False
# 3908      2900.0   4.0      2.0    4     6896.551724                False
# 1501      1500.0   2.0      1.0    2     4000.000000                False
# 3068      1232.0   2.0      1.0    2     5650.162338                False
# ...          ...   ...      ...  ...             ...                  ...
# 9376      1080.0   2.0      3.0    2     5925.925926                False
# 7294      1242.0   2.0      2.0    2     5233.494364                False
# 1344      1355.0   3.0      0.0    4     9963.099631                False
# 7296      2856.0   5.0      0.0    4     5409.663866                False
# 1289      1200.0   3.0      2.0    3     3833.333333                False
#
#       1st Phase JP Nagar  2nd Phase Judicial Layout  2nd Stage Nagarbhavi  \
# ...

# %%
print(X.columns)
# Out:
# Index(['total_sqft', 'bath', 'balcony', 'bhk', 'price_per_sqft',
#        '1st Block Jayanagar', '1st Phase JP Nagar',
#        '2nd Phase Judicial Layout', '2nd Stage Nagarbhavi',
#        '5th Phase JP Nagar',
#        ...
#        'Vishveshwarya Layout', 'Vishwapriya Layout', 'Vittasandra',
#        'Whitefield', 'Yelachenahalli', 'Yelahanka', 'Yelahanka New Town',
#        'Yelenahalli', 'Yeshwanthpur', 'other'],
#       dtype='object', length=243)

# %%
def predict_price(location,total_sqft,bath,balcony,bhk):
    loc_index = np.where(X.columns==location)[0]
    print(f"Location: {loc_index}")
    x = np.zeros(len(X.columns))
    x[0]=total_sqft
    x[1]=bath
    x[2]=balcony
    x[3]=bhk
    if loc_index >=0 :
        x[loc_index]=True
    else:
        others = np.where(X.columns=='other')[0][0]
        x[others]=True
    return drm.predict([x])[0]

# %%
print(predict_price('Whitefield',1800,2,1,3)*100000)
# Out:
# Location: [236]
# 4500000.0
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
import pickle
with open('house_prediction.pickle','wb') as f:
    pickle.dump(drm,f)

# %%
import json
columns = {
    'data_columns':[col.lower() for col in X.columns]
}
with open('house_feature_columns.json','w') as f:
    f.write(json.dumps(columns))
